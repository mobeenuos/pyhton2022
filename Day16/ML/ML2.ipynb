# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
height = [167,152,158,175,175,178,178]
weight = [72,59,45,94,94,74,62]

plt.scatter(height,weight)
